# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Boxplot

# %%
# Importando base de dados
base = pd.read_csv('../Dados/Trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
plt.boxplot(base.Volume)
plt.title('Árvores')
plt.xlabel('Volume')
# Out:
# Text(0.5, 0, 'Volume')

# %%
plt.boxplot(base.Volume, vert = False, showfliers = False)
plt.title('Árvores')
plt.xlabel('Volume')
# Out:
# Text(0.5, 0, 'Volume')

# %%
plt.boxplot(base.Volume, vert = False, showfliers = True, notch = True, patch_artist = True)
plt.title('Árvores')
plt.xlabel('Volume')
# Out:
# Text(0.5, 0, 'Volume')

# %%
plt.boxplot(base)

# %%
plt.boxplot(base.Volume, vert = False)
plt.boxplot(base.Girth, vert = False)
plt.boxplot(base.Height, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12948bc50>,
#   <matplotlib.lines.Line2D at 0x12948bf28>],
#  'caps': [<matplotlib.lines.Line2D at 0x12949a240>,
#   <matplotlib.lines.Line2D at 0x12949a518>],
#  'boxes': [<matplotlib.lines.Line2D at 0x129474208>],
#  'medians': [<matplotlib.lines.Line2D at 0x12949a7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12949aac8>],
#  'means': []}

# %%
sns.boxplot(base.Volume).set_title('Árvores')
sns.boxplot(data = base)
# Out:
# <AxesSubplot:title={'center':'Árvores'}, xlabel='Volume'>
