# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Histograma

# %%
# Importando base de dados
base = pd.read_csv('../Dados/Trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
h = np.histogram(base.iloc[:, 1], bins = 'auto')
plt.hist(base.iloc[:, 1], bins = 'auto')
plt.title('Árvore')
plt.ylabel('Frequência')
plt.xlabel('Altura')
# Out:
# Text(0.5, 0, 'Altura')

# %%
# Densidade
plt.hist(base.iloc[:, 1], bins = 10)
# Out:
# (array([3., 1., 2., 3., 2., 6., 2., 8., 1., 3.]),
#  array([63. , 65.4, 67.8, 70.2, 72.6, 75. , 77.4, 79.8, 82.2, 84.6, 87. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(base['Height'], color = 'blue', hist_kws = {'edgecolor': 'black'})
# Out:
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/4236015632.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base['Height'], color = 'blue', hist_kws = {'edgecolor': 'black'})
# <AxesSubplot: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(base['Height'], color = 'blue', hist_kws = {'edgecolor': 'black'}, bins = 6)
# Out:
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/353117865.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base['Height'], color = 'blue', hist_kws = {'edgecolor': 'black'}, bins = 6)
# <AxesSubplot: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(base['Height'], color = 'blue', hist_kws = {'edgecolor': 'black'}, bins = 6, hist = True, kde = True)
# Out:
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/2602356154.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base['Height'], color = 'blue', hist_kws = {'edgecolor': 'black'}, bins = 6, hist = True, kde = True)
# <AxesSubplot: xlabel='Height', ylabel='Density'>

# %%
# Histograma condicional - comparação de uma variável contínua x categórica
sns.distplot(base.Volume, bins = 10, axlabel = 'Volume').set_title('Árvore')
# Out:
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/2470941015.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base.Volume, bins = 10, axlabel = 'Volume').set_title('Árvore')
# Text(0.5, 1.0, 'Árvore')

# %%
# Importando base de dados
base = pd.read_csv('../Dados/Chicken.csv')

agrupado = base.groupby(['feed'])['weight'].sum()
teste = base.loc[base['feed'] == 'horsebean']

# %%
plt.figure()
plt.subplot(3, 2, 1)
sns.distplot(base.loc[base['feed'] == 'horsebean'].weight).set_title('horsebean')

plt.subplot(3, 2, 2)
sns.distplot(base.loc[base['feed'] == 'casein'].weight).set_title('casein')

plt.subplot(3, 2, 3)
sns.distplot(base.loc[base['feed'] == 'linseed'].weight).set_title('linseed')

plt.subplot(3, 2, 4)
sns.distplot(base.loc[base['feed'] == 'meatmeal'].weight).set_title('meatmeal')

plt.subplot(3, 2, 5)
sns.distplot(base.loc[base['feed'] == 'soybean'].weight).set_title('soybean')

plt.subplot(3, 2, 6)
sns.distplot(base.loc[base['feed'] == 'sunflower'].weight).set_title('sunflower')
plt.tight_layout()
# Out:
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/1083429488.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base.loc[base['feed'] == 'horsebean'].weight).set_title('horsebean')
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/1083429488.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base.loc[base['feed'] == 'casein'].weight).set_title('casein')
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/1083429488.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base.loc[base['feed'] == 'linseed'].weight).set_title('linseed')
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/1083429488.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base.loc[base['feed'] == 'meatmeal'].weight).set_title('meatmeal')
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/1083429488.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base.loc[base['feed'] == 'soybean'].weight).set_title('soybean')
# /var/folders/nm/vld9byk130bb28cb7q9fs82c0000gn/T/ipykernel_10242/1083429488.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(base.loc[base['feed'] == 'sunflower'].weight).set_title('sunflower')
