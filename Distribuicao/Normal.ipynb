# %%
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Distribuição Normal

# %%
# Uma cesta de objetos, a média é 8 o desvio padrão é 2, qual a probabilidade de de tirar um objeto < 6 quilos
# cdf para valores menores < que
norm.cdf(6, 8, 2)
# Out:
# 0.15865525393145707

# %%
# sf para valores maior > que
norm.sf(6, 8, 2)
# Out:
# 0.8413447460685429

# %%
1 - norm.cdf(6, 8, 2)
# Out:
# 0.8413447460685429

# %%
# Qual a probabilidade de tirar um objeto < 6 e > 10
norm.cdf(6, 8, 2) + norm.sf(10, 8, 2)
# Out:
# 0.31731050786291415

# %%
# Qual a probabilidade de tirar um objeto < 10 e > 8
norm.cdf(10, 8, 2) - norm.cdf(8, 8, 2)
# Out:
# 0.3413447460685429

# %%
# Gerando uma amostra de tamnho 100 normal
dados = norm.rvs(size = 100)
dados
# Out:
# array([-1.64368195, -0.54664776,  1.10991632,  0.50591333,  0.08724939,
#         1.05126934, -0.36868824,  0.58281422,  0.45581196, -0.57037811,
#        -0.61535665, -0.55957153, -0.65782931, -1.16731994, -0.81581755,
#        -1.29836267,  0.11291955, -0.57630477,  0.14727263, -0.43100099,
#         0.3285178 , -0.57673717,  1.03113216, -2.04574518,  1.64302191,
#        -0.05959317, -0.16322197, -1.718491  ,  1.13063646, -0.85791151,
#         1.62461109, -0.31672869,  0.21509747,  0.1311304 , -0.70381011,
#        -0.02328202,  0.47036234,  0.30157075,  0.81538012,  1.1081883 ,
#         0.36822296,  0.34969983,  0.75902631,  1.80003842, -0.98585459,
#        -1.01615131,  1.17793573, -0.00428177,  0.68899497,  1.72186807,
#        -0.20573916, -0.36794188,  1.55083073, -0.40951644,  2.03158522,
#         1.33978981, -0.50106154, -0.56966348, -1.36664241, -0.77193401,
#         0.60324948, -0.54392873, -0.06817596,  0.40212845,  1.34850112,
#        -1.01694692,  0.06424174, -0.01975809,  0.95703196,  2.25624751,
#        -0.93596671, -1.04478857,  1.97171726, -0.1534581 ,  0.47563343,
#         1.63744076, -0.08955686,  1.62467347, -0.84811038, -0.8038361 ,
#         0.54623085, -0.00336737,  0.2286209 , -1.41616226,  0.03470685,
#        -1.6528752 ,  1.44660279, -0.9228566 , -0.26504458,  0.91761813,
#         0.2194064 , -0.69917036,  1.42796909, -0.86973328, -1.63040337,
#         0.68846204, -0.45834192, -1.98701627,  0.71413989,  0.51924268])

# %%
stats.probplot(dados, plot = plt)
# Out:
# ((array([-2.46203784, -2.12570747, -1.93122778, -1.79044653, -1.67819304,
#          -1.58381122, -1.50174123, -1.42869743, -1.36256869, -1.30191411,
#          -1.24570419, -1.19317644, -1.14374949, -1.09696931, -1.05247413,
#          -1.00997067, -0.96921765, -0.93001393, -0.89218993, -0.85560121,
#          -0.82012357, -0.78564937, -0.75208458, -0.71934648, -0.68736185,
#          -0.65606548, -0.62539893, -0.59530962, -0.56574992, -0.53667655,
#          -0.50804994, -0.47983378, -0.45199463, -0.42450149, -0.39732558,
#          -0.37044003, -0.34381966, -0.31744076, -0.29128096, -0.26531902,
#          -0.23953472, -0.21390872, -0.18842244, -0.16305799, -0.13779803,
#          -0.1126257 , -0.08752455, -0.06247843, -0.03747145, -0.01248789,
#           0.01248789,  0.03747145,  0.06247843,  0.08752455,  0.1126257 ,
#           0.13779803,  0.16305799,  0.18842244,  0.21390872,  0.23953472,
#           0.26531902,  0.29128096,  0.31744076,  0.34381966,  0.37044003,
#           0.39732558,  0.42450149,  0.45199463,  0.47983378,  0.50804994,
#           0.53667655,  0.56574992,  0.59530962,  0.62539893,  0.65606548,
#           0.68736185,  0.71934648,  0.75208458,  0.78564937,  0.82012357,
#           0.85560121,  0.89218993,  0.93001393,  0.96921765,  1.00997067,
#           1.05247413,  1.09696931,  1.14374949,  1.19317644,  1.24570419,
#           1.30191411,  1.36256869,  1.42869743,  1.50174123,  1.58381122,
#           1.67819304,  1.79044653,  1.93122778,  2.12570747,  2.46203784]),
#   array([-2.04574518, -1.98701627, -1.718491  , -1.6528752 , -1.64368195,
#          -1.63040337, -1.41616226, -1.36664241, -1.29836267, -1.16731994,
#          -1.04478857, -1.01694692, -1.01615131, -0.98585459, -0.93596671,
#          -0.9228566 , -0.86973328, -0.85791151, -0.84811038, -0.81581755,
#          -0.8038361 , -0.77193401, -0.70381011, -0.69917036, -0.65782931,
#          -0.61535665, -0.57673717, -0.57630477, -0.57037811, -0.56966348,
#          -0.55957153, -0.54664776, -0.54392873, -0.50106154, -0.45834192,
#          -0.43100099, -0.40951644, -0.36868824, -0.36794188, -0.31672869,
#          -0.26504458, -0.20573916, -0.16322197, -0.1534581 , -0.08955686,
#          -0.06817596, -0.05959317, -0.02328202, -0.01975809, -0.00428177,
#          -0.00336737,  0.03470685,  0.06424174,  0.08724939,  0.11291955,
#           0.1311304 ,  0.14727263,  0.21509747,  0.2194064 ,  0.2286209 ,
#           0.30157075,  0.3285178 ,  0.34969983,  0.36822296,  0.40212845,
#           0.45581196,  0.47036234,  0.47563343,  0.50591333,  0.51924268,
#           0.54623085,  0.58281422,  0.60324948,  0.68846204,  0.68899497,
#           0.71413989,  0.75902631,  0.81538012,  0.91761813,  0.95703196,
#           1.03113216,  1.05126934,  1.1081883 ,  1.10991632,  1.13063646,
#           1.17793573,  1.33978981,  1.34850112,  1.42796909,  1.44660279,
#           1.55083073,  1.62461109,  1.62467347,  1.63744076,  1.64302191,
#           1.72186807,  1.80003842,  1.97171726,  2.03158522,  2.25624751])),
#  (0.9957042024430761, 0.05379907840177416, 0.9955858141534312))

# %%
# Realizando o teste de Shapiro
stats.shapiro(dados)
# Out:
# (0.9867887496948242, 0.4235791862010956)
